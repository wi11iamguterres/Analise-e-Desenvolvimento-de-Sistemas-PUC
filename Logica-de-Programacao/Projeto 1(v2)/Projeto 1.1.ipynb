# %%
meses=[1=="Janeiro",
       2=="Fevereiro",
       3=="Março"]

try:
  for m in range(1,4):
    temp=float(input("Informe a temperatura entre -60ºC e +50ºC do mês {}: ".format(m)).strip())
    while temp<-60 or temp>50:
      print("Temperatura inválida.")
      temp=float(input("Informe a temperatura entre -60ºC e +50ºC do mês {}: ".format(m)).strip())


except ValueError:
  print("Caracter inválido.")
  temp=float(input("Informe a temperatura entre -60ºC e +50ºC do mês {}: ".format(m)).strip())
  while temp<-60 or temp>50:
    print("Temperatura inválida.")
    temp=float(input("Informe a temperatura entre -60ºC e +50ºC do mês {}: ".format(m)).strip())
# Out:
# Informe a temperatura entre -60ºC e +50ºC do mês 1: a
# Caracter inválido.
# Informe a temperatura entre -60ºC e +50ºC do mês 1: 99
# Temperatura inválida.
# Informe a temperatura entre -60ºC e +50ºC do mês 1: a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-720610116.py in <cell line: 0>()
#       6   for m in range(1,4):
# ----> 7     temp=float(input("Informe a temperatura entre -60ºC e +50ºC do mês {}: ".format(m)).strip())
#       8     while temp<-60 or temp>50:
#
# ValueError: could not convert string to float: 'a'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-720610116.py in <cell line: 0>()
#      16   while temp<-60 or temp>50:
#      17     print("Temperatura inválida.")
# ...
